# %% [markdown]
# <a href="https://colab.research.google.com/github/mominulhaque666/Group_5_CSE445_3_Spring_21/blob/main/ipynb/T20WinnerPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 50)

# %%
# Upload the audit risk dataset

matches = 'https://raw.githubusercontent.com/nahidosen/Group_5_CSE445_3_Spring_21/main/dataset/IT20%20.csv'

# %%
# Read the audit risk dataset

match_df = pd.read_csv(matches)
match_df
# Out:
#           dates                    venue          city     home_team  \
# 0    2005-02-17                Eden Park      Auckland   New Zealand
# 1    2005-06-13            The Rose Bowl   Southampton       England
# 2    2005-10-21    New Wanderers Stadium  Johannesburg  South Africa
# 3    2006-01-09  Brisbane Cricket Ground      Brisbane     Australia
# 4    2006-02-16                Eden Park      Auckland   New Zealand
# ..          ...                      ...           ...           ...
# 966  2021-03-17     Sheikh Zayed Stadium     Abu Dhabi          none
# 967  2021-03-18    Narendra Modi Stadium     Ahmedabad         India
# 968  2021-03-19     Sheikh Zayed Stadium     Abu Dhabi          none
# 969  2021-03-20    Narendra Modi Stadium     Ahmedabad         India
# 970  2021-03-20     Sheikh Zayed Stadium     Abu Dhabi          none
#
#            team_1        team_2  total_matches_team1  total_matches_team2  \
# 0     New Zealand     Australia                  NaN                  0.0
# 1         England     Australia                  NaN                  1.0
# 2    South Africa   New Zealand                  NaN                  NaN
# 3       Australia  South Africa                  2.0                  NaN
# 4     West Indies   New Zealand                  NaN                  NaN
# ..            ...           ...                  ...                  ...
# 966   Afghanistan      Zimbabwe                  NaN                  NaN
# 967         India       England                  NaN                  NaN
# 968   Afghanistan      Zimbabwe                  NaN                  NaN
# 969         India       England                  NaN                  NaN
# 970   Afghanistan      Zimbabwe                  NaN                  NaN
#
#      toss_winner  total_wins_team1  total_wins_team2 toss_decision  \
# 0      Australia               NaN               1.0           bat
# 1        England               NaN               NaN           bat
# 2    New Zealand               NaN               NaN         field
# 3      Australia               NaN               NaN           bat
# 4    New Zealand               NaN               NaN         field
# ..           ...               ...               ...           ...
# 966     Zimbabwe               NaN               NaN         field
# 967      England               NaN               NaN         field
# 968  Afghanistan               NaN               NaN           bat
# 969      England               NaN               NaN         field
# 970  Afghanistan               NaN               NaN           bat
#
#                   umpire_1        umpire_2 match_winner  head_to_head  \
# 0                BF Bowden         AL Hill    Australia           1.0
# 1                 NJ Llong       JW Lloyds      England           NaN
# 2                IL Howell      BG Jerling  New Zealand           NaN
# 3             BNJ Oxenford        RL Parry    Australia           NaN
# 4                BF Bowden         AL Hill  New Zealand           NaN
# ..                     ...             ...          ...           ...
# 966              Aleem Dar  Izatullah Safi  Afghanistan           NaN
# 967  KN Ananthapadmanabhan     Nitin Menon        India           NaN
# 968     Ahmed Shah Durrani       Aleem Dar  Afghanistan           NaN
# 969           AK Chaudhary     Nitin Menon        India           NaN
# 970              Aleem Dar  Izatullah Safi  Afghanistan           NaN
#
#      total_loses_team1  total_loses_team2  win_ratio_team1  win_ratio_team2  \
# 0                  NaN                NaN              NaN              NaN
# 1                  NaN                NaN              NaN              NaN
# 2                  NaN                NaN              NaN              NaN
# 3                  NaN                NaN              NaN              NaN
# 4                  NaN                NaN              NaN              NaN
# ..                 ...                ...              ...              ...
# 966                NaN                NaN              NaN              NaN
# 967                NaN                NaN              NaN              NaN
# 968                NaN                NaN              NaN              NaN
# 969                NaN                NaN              NaN              NaN
# 970                NaN                NaN              NaN              NaN
#
#      lose_ratio_team1  lose_ratio_team2
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ..                ...               ...
# 966               NaN               NaN
# 967               NaN               NaN
# 968               NaN               NaN
# 969               NaN               NaN
# 970               NaN               NaN
#
# [971 rows x 22 columns]

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dates                971 non-null    object
#  1   venue                971 non-null    object
#  2   city                 971 non-null    object
#  3   home_team            971 non-null    object
#  4   team_1               971 non-null    object
#  5   team_2               971 non-null    object
#  6   total_matches_team1  80 non-null     float64
#  7   total_matches_team2  56 non-null     float64
#  8   toss_winner          971 non-null    object
#  9   total_wins_team1     0 non-null      float64
#  10  total_wins_team2     1 non-null      float64
#  11  toss_decision        971 non-null    object
#  12  umpire_1             971 non-null    object
#  13  umpire_2             971 non-null    object
#  14  match_winner         971 non-null    object
#  15  head_to_head         3 non-null      float64
#  16  total_loses_team1    0 non-null      float64
#  17  total_loses_team2    0 non-null      float64
#  18  win_ratio_team1      0 non-null      float64
#  19  win_ratio_team2      0 non-null      float64
#  20  lose_ratio_team1     0 non-null      float64
#  21  lose_ratio_team2     0 non-null      float64
# dtypes: float64(11), object(11)
# memory usage: 167.0+ KB

# %% [markdown]
# # EDA

# %%
# Check if there any column left contains missing value
match_df.isnull().sum()
# Out:
# dates                    0
# venue                    0
# city                     0
# home_team                0
# team_1                   0
# team_2                   0
# total_matches_team1    891
# total_matches_team2    915
# toss_winner              0
# total_wins_team1       971
# total_wins_team2       970
# toss_decision            0
# umpire_1                 0
# umpire_2                 0
# match_winner             0
# head_to_head           968
# total_loses_team1      971
# total_loses_team2      971
# win_ratio_team1        971
# win_ratio_team2        971
# lose_ratio_team1       971
# lose_ratio_team2       971
# dtype: int64

# %%
# Drop the columns which contains null value
match_df = match_df.dropna(axis=1)

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dates          971 non-null    object
#  1   venue          971 non-null    object
#  2   city           971 non-null    object
#  3   home_team      971 non-null    object
#  4   team_1         971 non-null    object
#  5   team_2         971 non-null    object
#  6   toss_winner    971 non-null    object
#  7   toss_decision  971 non-null    object
#  8   umpire_1       971 non-null    object
#  9   umpire_2       971 non-null    object
#  10  match_winner   971 non-null    object
# dtypes: object(11)
# memory usage: 83.6+ KB

# %%
# match_df dataframe description
match_df.describe
# Out:
# <bound method NDFrame.describe of           dates                    venue          city     home_team  \
# 0    2005-02-17                Eden Park      Auckland   New Zealand
# 1    2005-06-13            The Rose Bowl   Southampton       England
# 2    2005-10-21    New Wanderers Stadium  Johannesburg  South Africa
# 3    2006-01-09  Brisbane Cricket Ground      Brisbane     Australia
# 4    2006-02-16                Eden Park      Auckland   New Zealand
# ..          ...                      ...           ...           ...
# 966  2021-03-17     Sheikh Zayed Stadium     Abu Dhabi          none
# 967  2021-03-18    Narendra Modi Stadium     Ahmedabad         India
# 968  2021-03-19     Sheikh Zayed Stadium     Abu Dhabi          none
# 969  2021-03-20    Narendra Modi Stadium     Ahmedabad         India
# 970  2021-03-20     Sheikh Zayed Stadium     Abu Dhabi          none
#
#            team_1        team_2  toss_winner toss_decision  \
# 0     New Zealand     Australia    Australia           bat
# 1         England     Australia      England           bat
# 2    South Africa   New Zealand  New Zealand         field
# 3       Australia  South Africa    Australia           bat
# 4     West Indies   New Zealand  New Zealand         field
# ..            ...           ...          ...           ...
# 966   Afghanistan      Zimbabwe     Zimbabwe         field
# 967         India       England      England         field
# 968   Afghanistan      Zimbabwe  Afghanistan           bat
# 969         India       England      England         field
# 970   Afghanistan      Zimbabwe  Afghanistan           bat
#
#                   umpire_1        umpire_2 match_winner
# 0                BF Bowden         AL Hill    Australia
# 1                 NJ Llong       JW Lloyds      England
# 2                IL Howell      BG Jerling  New Zealand
# 3             BNJ Oxenford        RL Parry    Australia
# 4                BF Bowden         AL Hill  New Zealand
# ..                     ...             ...          ...
# 966              Aleem Dar  Izatullah Safi  Afghanistan
# 967  KN Ananthapadmanabhan     Nitin Menon        India
# 968     Ahmed Shah Durrani       Aleem Dar  Afghanistan
# 969           AK Chaudhary     Nitin Menon        India
# 970              Aleem Dar  Izatullah Safi  Afghanistan
#
# [971 rows x 11 columns]>

# %%
# View to 10 rows
match_df.head(10)
# Out:
#         dates                    venue          city     home_team  \
# 0  2005-02-17                Eden Park      Auckland   New Zealand
# 1  2005-06-13            The Rose Bowl   Southampton       England
# 2  2005-10-21    New Wanderers Stadium  Johannesburg  South Africa
# 3  2006-01-09  Brisbane Cricket Ground      Brisbane     Australia
# 4  2006-02-16                Eden Park      Auckland   New Zealand
# 5  2006-02-24    New Wanderers Stadium  Johannesburg  South Africa
# 6  2006-06-15            The Rose Bowl   Southampton       England
# 7  2006-08-28            County Ground       Bristol       England
# 8  2006-12-01    New Wanderers Stadium  Johannesburg  South Africa
# 9  2006-12-22          Westpac Stadium    Wellington   New Zealand
#
#          team_1        team_2   toss_winner toss_decision      umpire_1  \
# 0   New Zealand     Australia     Australia           bat     BF Bowden
# 1       England     Australia       England           bat      NJ Llong
# 2  South Africa   New Zealand   New Zealand         field     IL Howell
# 3     Australia  South Africa     Australia           bat  BNJ Oxenford
# 4   West Indies   New Zealand   New Zealand         field     BF Bowden
# 5  South Africa     Australia  South Africa           bat     M Erasmus
# 6       England     Sri Lanka     Sri Lanka           bat      IJ Gould
# 7       England      Pakistan       England           bat    PJ Hartley
# 8  South Africa         India  South Africa           bat     IL Howell
# 9   New Zealand     Sri Lanka   New Zealand           bat       AL Hill
#
#      umpire_2  match_winner
# 0     AL Hill     Australia
# 1   JW Lloyds       England
# 2  BG Jerling   New Zealand
# 3    RL Parry     Australia
# 4     AL Hill   New Zealand
# 5   KH Hurter  South Africa
# 6    NJ Llong     Sri Lanka
# 7    NJ Llong      Pakistan
# 8  BG Jerling         India
# 9   EA Watkin     Sri Lanka

# %%
# shape
match_df.shape
# Out:
# (971, 11)

# %%
# check all the unique values
match_df.nunique()
# Out:
# dates            722
# venue            138
# city             117
# home_team         28
# team_1            48
# team_2            46
# toss_winner       46
# toss_decision      2
# umpire_1         147
# umpire_2         152
# match_winner      42
# dtype: int64

# %%
# total appearance of each team in team_1 column
match_df['team_1'].value_counts()
# Out:
# New Zealand                 81
# Australia                   80
# India                       77
# England                     70
# South Africa                69
# Afghanistan                 62
# Pakistan                    57
# Bangladesh                  56
# West Indies                 51
# Sri Lanka                   51
# Ireland                     43
# Netherlands                 28
# Zimbabwe                    28
# United Arab Emirates        27
# Hong Kong                   27
# Canada                      19
# Malaysia                    17
# Kenya                       16
# Nepal                       10
# Oman                        10
# Namibia                     10
# Bermuda                     10
# Scotland                     7
# Singapore                    6
# Papua New Guinea             5
# Kuwait                       5
# Denmark                      5
# Thailand                     4
# Guernsey                     4
# Uganda                       4
# Philippines                  3
# Maldives                     3
# Ghana                        3
# Germany                      3
# Jersey                       3
# Bulgaria                     2
# Botswana                     2
# Cayman Islands               2
# United States of America     2
# Bahrain                      1
# Qatar                        1
# Bhutan                       1
# Romania                      1
# Saudi Arabia                 1
# Iran                         1
# Isle of Man                  1
# Italy                        1
# Nigeria                      1
# Name: team_1, dtype: int64

# %%
# total appearance of each team in team_2 column
match_df['team_2'].value_counts()
# Out:
# Pakistan                    100
# West Indies                  78
# Sri Lanka                    77
# India                        63
# New Zealand                  61
# England                      61
# South Africa                 57
# Australia                    56
# Zimbabwe                     49
# Ireland                      43
# Scotland                     42
# Netherlands                  36
# Bangladesh                   35
# Oman                         21
# Nepal                        21
# United Arab Emirates         18
# Afghanistan                  16
# Papua New Guinea             15
# Hong Kong                    15
# Kenya                        12
# Vanuatu                       9
# Singapore                     9
# Nigeria                       7
# Jersey                        7
# Namibia                       6
# United States of America      6
# Qatar                         5
# Malaysia                      5
# Botswana                      5
# Norway                        4
# Cayman Islands                4
# Maldives                      4
# Thailand                      4
# Italy                         3
# Romania                       2
# Canada                        2
# Germany                       2
# Guernsey                      2
# Bermuda                       2
# Philippines                   1
# Denmark                       1
# Ghana                         1
# Bahrain                       1
# Bulgaria                      1
# Bhutan                        1
# Kuwait                        1
# Name: team_2, dtype: int64

# %%
# total appearance of each team in home_team column
match_df['home_team'].value_counts()
# Out:
# none                    405
# New Zealand              70
# South Africa             62
# India                    51
# England                  48
# Australia                46
# West Indies              43
# Sri Lanka                42
# Bangladesh               38
# United Arab Emirates     27
# Zimbabwe                 24
# Pakistan                 18
# Ireland                  16
# Malaysia                 15
# Netherlands              12
# Oman                      7
# Singapore                 6
# Kenya                     5
# Scotland                  5
# Bermuda                   5
# Namibia                   4
# Thailand                  4
# Uganda                    4
# Papua New Guinea          4
# Nepal                     3
# Romania                   3
# Hong Kong                 2
# Guernsey                  2
# Name: home_team, dtype: int64

# %%
# plot percantage of home_team
plt.figure(figsize=(30,20))
plt.title(' Team as Home team')
plt.pie(list(match_df['home_team'].value_counts()), labels=list(match_df['home_team'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
# teams winning the toss
match_df['toss_winner'].value_counts()
# Out:
# Pakistan                    79
# Australia                   73
# New Zealand                 69
# West Indies                 67
# England                     66
# India                       64
# South Africa                60
# Sri Lanka                   58
# Bangladesh                  48
# Ireland                     48
# Afghanistan                 39
# Zimbabwe                    39
# Netherlands                 33
# United Arab Emirates        25
# Hong Kong                   22
# Scotland                    19
# Oman                        18
# Malaysia                    14
# Kenya                       14
# Nepal                       13
# Papua New Guinea            11
# Canada                      10
# Singapore                   10
# Thailand                     7
# Namibia                      7
# Vanuatu                      6
# Bermuda                      5
# Botswana                     5
# Denmark                      4
# Nigeria                      4
# Jersey                       4
# Germany                      4
# United States of America     3
# Ghana                        3
# Cayman Islands               3
# Guernsey                     3
# Kuwait                       2
# Qatar                        2
# Italy                        2
# Bulgaria                     2
# Maldives                     1
# Philippines                  1
# Isle of Man                  1
# Bhutan                       1
# Bahrain                      1
# Romania                      1
# Name: toss_winner, dtype: int64

# %%
# team toss winning percentage
plt.figure(figsize=(30,20))
plt.title(' Team Toss Winning Percentage')
plt.pie(list(match_df['toss_winner'].value_counts()), labels=list(match_df['toss_winner'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
# team as match winner
match_df['match_winner'].value_counts()
# Out:
# Pakistan                    98
# India                       90
# New Zealand                 77
# Australia                   72
# South Africa                71
# England                     70
# Sri Lanka                   59
# West Indies                 58
# Afghanistan                 54
# Ireland                     39
# Netherlands                 36
# Bangladesh                  30
# Scotland                    23
# United Arab Emirates        21
# Zimbabwe                    17
# Nepal                       16
# Hong Kong                   15
# Oman                        14
# Papua New Guinea            13
# Malaysia                    12
# Namibia                     12
# Kenya                       11
# Singapore                    9
# Canada                       8
# Jersey                       6
# Bermuda                      5
# Guernsey                     4
# Vanuatu                      4
# Germany                      4
# Kuwait                       3
# Uganda                       2
# Maldives                     2
# Romania                      2
# Denmark                      2
# Nigeria                      2
# Italy                        2
# United States of America     2
# Qatar                        2
# Thailand                     1
# Philippines                  1
# Bulgaria                     1
# Bahrain                      1
# Name: match_winner, dtype: int64

# %%
# each team match winning percentage
plt.figure(figsize=(30,20))
plt.title(' Team Winning Percentage')
plt.pie(list(match_df['match_winner'].value_counts()), labels=list(match_df['match_winner'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
toss_wins = match_df['toss_winner'].value_counts(sort=True).sort_index()
match_wins = match_df['match_winner'].value_counts(sort=True).sort_index()

# %%
# Now plot toss & match winner together

fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Count of tosses won')
ax1.set_title("Toss Winners")
toss_wins.plot(kind='bar')

ax2 = fig.add_subplot(122)
match_wins.plot(kind='bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('Count of matches won')
ax2.set_title("Match Winners")
# Out:
# Text(0.5, 1.0, 'Match Winners')

# %%
home_team = match_df['home_team'].value_counts(sort=True).sort_index()
match_wins = match_df['match_winner'].value_counts(sort=True).sort_index()

# %%
# Now plot home team & match winner together

fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Appearance as Home Team')
ax1.set_title("Home Team")
home_team.plot(kind='bar')

ax2 = fig.add_subplot(122)
match_wins.plot(kind='bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('Count of matches won')
ax2.set_title("Match Winners")
# Out:
# Text(0.5, 1.0, 'Match Winners')

# %%
# teams batting first
batting_first = match_df[match_df['toss_decision'] == 'bat']

# %%
batting_first.head(10)
# Out:
#          dates                    venue          city     home_team  \
# 0   2005-02-17                Eden Park      Auckland   New Zealand
# 1   2005-06-13            The Rose Bowl   Southampton       England
# 3   2006-01-09  Brisbane Cricket Ground      Brisbane     Australia
# 5   2006-02-24    New Wanderers Stadium  Johannesburg  South Africa
# 6   2006-06-15            The Rose Bowl   Southampton       England
# 7   2006-08-28            County Ground       Bristol       England
# 8   2006-12-01    New Wanderers Stadium  Johannesburg  South Africa
# 9   2006-12-22          Westpac Stadium    Wellington   New Zealand
# 11  2007-01-09    Sydney Cricket Ground        Sydney     Australia
# 12  2007-06-28          Kennington Oval        London       England
#
#           team_1        team_2   toss_winner toss_decision      umpire_1  \
# 0    New Zealand     Australia     Australia           bat     BF Bowden
# 1        England     Australia       England           bat      NJ Llong
# 3      Australia  South Africa     Australia           bat  BNJ Oxenford
# 5   South Africa     Australia  South Africa           bat     M Erasmus
# 6        England     Sri Lanka     Sri Lanka           bat      IJ Gould
# 7        England      Pakistan       England           bat    PJ Hartley
# 8   South Africa         India  South Africa           bat     IL Howell
# 9    New Zealand     Sri Lanka   New Zealand           bat       AL Hill
# 11     Australia       England     Australia           bat     PD Parker
# 12       England   West Indies   West Indies           bat    PJ Hartley
#
#       umpire_2  match_winner
# 0      AL Hill     Australia
# 1    JW Lloyds       England
# 3     RL Parry     Australia
# 5    KH Hurter  South Africa
# 6     NJ Llong     Sri Lanka
# 7     NJ Llong      Pakistan
# 8   BG Jerling         India
# 9    EA Watkin     Sri Lanka
# 11    RL Parry     Australia
# 12    NJ Llong   West Indies

# %%
# teams winning percentage while batting first
plt.figure(figsize=(30,20))
plt.title(' Team Winning Percentage at batting first')
plt.pie(list(batting_first['match_winner'].value_counts()), labels=list(batting_first['match_winner'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
bat_first = batting_first['toss_winner'].value_counts(sort=True).sort_index()
match_wins = batting_first['match_winner'].value_counts(sort=True).sort_index()

# %%
# plot batting first & match winning
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Team total batting first')
ax1.set_title("Bat First")
bat_first.plot(kind='bar')

ax2 = fig.add_subplot(122)
match_wins.plot(kind='bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('Count of matches won')
ax2.set_title("Match Winners")
# Out:
# Text(0.5, 1.0, 'Match Winners')

# %%
# team bowling first
bowling_first = match_df[match_df['toss_decision'] == 'field']

# %%
bowling_first.head(10)
# Out:
#          dates                  venue          city     home_team  \
# 2   2005-10-21  New Wanderers Stadium  Johannesburg  South Africa
# 4   2006-02-16              Eden Park      Auckland   New Zealand
# 10  2006-12-26              Eden Park      Auckland   New Zealand
# 14  2007-09-01   Gymkhana Club Ground       Nairobi         Kenya
# 15  2007-09-02   Gymkhana Club Ground       Nairobi          none
# 17  2007-09-11  New Wanderers Stadium  Johannesburg  South Africa
# 18  2007-09-12              Kingsmead        Durban          none
# 19  2007-09-12              Kingsmead        Durban          none
# 21  2007-09-13  New Wanderers Stadium  Johannesburg          none
# 23  2007-09-14              Kingsmead        Durban          none
#
#           team_1       team_2   toss_winner toss_decision     umpire_1  \
# 2   South Africa  New Zealand   New Zealand         field    IL Howell
# 4    West Indies  New Zealand   New Zealand         field    BF Bowden
# 10   New Zealand    Sri Lanka   New Zealand         field    BF Bowden
# 14         Kenya   Bangladesh    Bangladesh         field     R DMello
# 15    Bangladesh     Pakistan    Bangladesh         field     R DMello
# 17  South Africa  West Indies  South Africa         field    MR Benson
# 18         Kenya  New Zealand   New Zealand         field  BR Doctrove
# 19      Pakistan     Scotland      Scotland         field     SJ Davis
# 21    Bangladesh  West Indies    Bangladesh         field    MR Benson
# 23      Pakistan        India         India         field  BR Doctrove
#
#       umpire_2  match_winner
# 2   BG Jerling   New Zealand
# 4      AL Hill   New Zealand
# 10     AL Hill   New Zealand
# 14     SR Modi    Bangladesh
# 15     SR Modi      Pakistan
# 17   DJ Harper  South Africa
# 18  SJA Taufel   New Zealand
# 19  SJA Taufel      Pakistan
# 21    NJ Llong    Bangladesh
# 23  SJA Taufel      Pakistan

# %%
# teams winning while bowling first percentage
plt.figure(figsize=(30,20))
plt.title(' Team Winning Percentage at bowling first')
plt.pie(list(bowling_first['match_winner'].value_counts()), labels=list(bowling_first['match_winner'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
bowl_first = bowling_first['toss_winner'].value_counts(sort=True).sort_index()
match_wins = bowling_first['match_winner'].value_counts(sort=True).sort_index()

# %%
# plot match win and bowl first
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Team total bowling first')
ax1.set_title("Bowl First")
bowl_first.plot(kind='bar')

ax2 = fig.add_subplot(122)
match_wins.plot(kind='bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('Count of matches won')
ax2.set_title("Match Winners")
# Out:
# Text(0.5, 1.0, 'Match Winners')

# %%
# total win for each team batting first
batting_first['match_winner'].value_counts().sort_index()
# Out:
# Afghanistan                 38
# Australia                   39
# Bahrain                      1
# Bangladesh                  10
# Bermuda                      4
# Bulgaria                     1
# Canada                       5
# Denmark                      2
# England                     30
# Guernsey                     1
# Hong Kong                    8
# India                       24
# Ireland                     20
# Jersey                       3
# Kenya                        8
# Malaysia                    11
# Maldives                     1
# Namibia                      7
# Nepal                        6
# Netherlands                 19
# New Zealand                 29
# Nigeria                      1
# Oman                         6
# Pakistan                    55
# Papua New Guinea             8
# Qatar                        2
# Romania                      2
# Scotland                    12
# Singapore                    7
# South Africa                26
# Sri Lanka                   30
# Uganda                       1
# United Arab Emirates        10
# United States of America     1
# Vanuatu                      4
# West Indies                 29
# Zimbabwe                    11
# Name: match_winner, dtype: int64

# %%
# total win for each team bowling first
bowling_first['match_winner'].value_counts().sort_index()
# Out:
# Afghanistan                 16
# Australia                   33
# Bangladesh                  20
# Bermuda                      1
# Canada                       3
# England                     40
# Germany                      4
# Guernsey                     3
# Hong Kong                    7
# India                       66
# Ireland                     19
# Italy                        2
# Jersey                       3
# Kenya                        3
# Kuwait                       3
# Malaysia                     1
# Maldives                     1
# Namibia                      5
# Nepal                       10
# Netherlands                 17
# New Zealand                 48
# Nigeria                      1
# Oman                         8
# Pakistan                    43
# Papua New Guinea             5
# Philippines                  1
# Scotland                    11
# Singapore                    2
# South Africa                45
# Sri Lanka                   29
# Thailand                     1
# Uganda                       1
# United Arab Emirates        11
# United States of America     1
# West Indies                 29
# Zimbabwe                     6
# Name: match_winner, dtype: int64

# %%
# team 1 as home team
home_team_one = match_df[match_df['home_team'] == match_df['team_1']]

# %%
home_team_one.head(10)
# Out:
#          dates                    venue          city     home_team  \
# 0   2005-02-17                Eden Park      Auckland   New Zealand
# 1   2005-06-13            The Rose Bowl   Southampton       England
# 2   2005-10-21    New Wanderers Stadium  Johannesburg  South Africa
# 3   2006-01-09  Brisbane Cricket Ground      Brisbane     Australia
# 5   2006-02-24    New Wanderers Stadium  Johannesburg  South Africa
# 6   2006-06-15            The Rose Bowl   Southampton       England
# 7   2006-08-28            County Ground       Bristol       England
# 8   2006-12-01    New Wanderers Stadium  Johannesburg  South Africa
# 9   2006-12-22          Westpac Stadium    Wellington   New Zealand
# 10  2006-12-26                Eden Park      Auckland   New Zealand
#
#           team_1        team_2   toss_winner toss_decision      umpire_1  \
# 0    New Zealand     Australia     Australia           bat     BF Bowden
# 1        England     Australia       England           bat      NJ Llong
# 2   South Africa   New Zealand   New Zealand         field     IL Howell
# 3      Australia  South Africa     Australia           bat  BNJ Oxenford
# 5   South Africa     Australia  South Africa           bat     M Erasmus
# 6        England     Sri Lanka     Sri Lanka           bat      IJ Gould
# 7        England      Pakistan       England           bat    PJ Hartley
# 8   South Africa         India  South Africa           bat     IL Howell
# 9    New Zealand     Sri Lanka   New Zealand           bat       AL Hill
# 10   New Zealand     Sri Lanka   New Zealand         field     BF Bowden
#
#       umpire_2  match_winner
# 0      AL Hill     Australia
# 1    JW Lloyds       England
# 2   BG Jerling   New Zealand
# 3     RL Parry     Australia
# 5    KH Hurter  South Africa
# 6     NJ Llong     Sri Lanka
# 7     NJ Llong      Pakistan
# 8   BG Jerling         India
# 9    EA Watkin     Sri Lanka
# 10     AL Hill   New Zealand

# %%
home_team_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 969
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dates          483 non-null    object
#  1   venue          483 non-null    object
#  2   city           483 non-null    object
#  3   home_team      483 non-null    object
#  4   team_1         483 non-null    object
#  5   team_2         483 non-null    object
#  6   toss_winner    483 non-null    object
#  7   toss_decision  483 non-null    object
#  8   umpire_1       483 non-null    object
#  9   umpire_2       483 non-null    object
#  10  match_winner   483 non-null    object
# dtypes: object(11)
# memory usage: 45.3+ KB

# %%
# team 1 winning percentage as home team
plt.figure(figsize=(30,20))
plt.title(' Team 1 Winning as home team')
plt.pie(list(home_team_one['match_winner'].value_counts()), labels=list(home_team_one['match_winner'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
# total win as home team
home_team_one['match_winner'].value_counts().sort_index()
# Out:
# Afghanistan              8
# Australia               48
# Bangladesh              24
# Bermuda                  3
# England                 43
# Hong Kong                5
# India                   53
# Ireland                 11
# Italy                    1
# Jersey                   1
# Kenya                    1
# Malaysia                10
# Namibia                  5
# Nepal                    9
# Netherlands             12
# New Zealand             46
# Oman                     5
# Pakistan                37
# Papua New Guinea         4
# Romania                  1
# Scotland                 6
# Singapore                5
# South Africa            49
# Sri Lanka               33
# Uganda                   2
# United Arab Emirates    14
# Vanuatu                  3
# West Indies             35
# Zimbabwe                 9
# Name: match_winner, dtype: int64

# %%
home_team_onee = home_team_one['team_1'].value_counts(sort=True).sort_index()
match_wins = bowling_first['match_winner'].value_counts(sort=True).sort_index()

# %%
# plot match win and as home team for team 1
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Team 1 as home team')
ax1.set_title("Team 1")
home_team_onee.plot(kind='bar')

ax2 = fig.add_subplot(122)
match_wins.plot(kind='bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('Count of matches won')
ax2.set_title("Match Winners")
# Out:
# Text(0.5, 1.0, 'Match Winners')

# %%
# team 2 as home team
home_team_two = match_df[match_df['home_team'] == match_df['team_2']]

# %%
home_team_two.head(10)
# Out:
#           dates                                    venue          city  \
# 4    2006-02-16                                Eden Park      Auckland
# 60   2008-12-26                                Eden Park      Auckland
# 101  2009-08-30                             Old Trafford    Manchester
# 124  2010-02-28                              AMI Stadium  Christchurch
# 230  2012-09-10                             Old Trafford    Manchester
# 245  2012-09-27  Pallekele International Cricket Stadium         Kandy
# 260  2012-10-30  Pallekele International Cricket Stadium         Kandy
# 290  2013-06-27                          Kennington Oval        London
# 372  2014-08-27                              Warner Park      St Kitts
# 399  2015-07-13               Civil Service Cricket Club       Belfast
#
#        home_team        team_1       team_2  toss_winner toss_decision  \
# 4    New Zealand   West Indies  New Zealand  New Zealand         field
# 60   New Zealand   West Indies  New Zealand  New Zealand           bat
# 101      England     Australia      England      England         field
# 124  New Zealand     Australia  New Zealand  New Zealand           bat
# 230      England  South Africa      England      England         field
# 245    Sri Lanka   New Zealand    Sri Lanka    Sri Lanka           bat
# 260    Sri Lanka   New Zealand    Sri Lanka    Sri Lanka         field
# 290      England   New Zealand      England      England         field
# 372  West Indies    Bangladesh  West Indies  West Indies           bat
# 399      Ireland         Nepal      Ireland      Ireland         field
#
#            umpire_1           umpire_2 match_winner
# 4         BF Bowden            AL Hill  New Zealand
# 60        BF Bowden            AL Hill  New Zealand
# 101        IJ Gould   RA Kettleborough      England
# 124     CB Gaffaney            AL Hill  New Zealand
# 230       RJ Bailey     RK Illingworth      England
# 245       Aleem Dar         SJA Taufel  New Zealand
# 260   REJ Martinesz  RSA Palliyaguruge    Sri Lanka
# 290  RK Illingworth        RT Robinson  New Zealand
# 372         PJ Nero          JS Wilson   Bangladesh
# 399    AK Chaudhary          JD Cloete      Ireland

# %%
home_team_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 4 to 964
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dates          83 non-null     object
#  1   venue          83 non-null     object
#  2   city           83 non-null     object
#  3   home_team      83 non-null     object
#  4   team_1         83 non-null     object
#  5   team_2         83 non-null     object
#  6   toss_winner    83 non-null     object
#  7   toss_decision  83 non-null     object
#  8   umpire_1       83 non-null     object
#  9   umpire_2       83 non-null     object
#  10  match_winner   83 non-null     object
# dtypes: object(11)
# memory usage: 7.8+ KB

# %%
# team 2 wins as home team
home_team_two['match_winner'].value_counts().sort_index()
# Out:
# Afghanistan              2
# Australia                7
# Bangladesh               1
# Bermuda                  2
# Bulgaria                 1
# England                  8
# Guernsey                 1
# India                   12
# Ireland                  1
# Malaysia                 1
# Netherlands              2
# New Zealand             13
# Pakistan                12
# Papua New Guinea         1
# Romania                  1
# Scotland                 1
# South Africa             5
# Sri Lanka                5
# United Arab Emirates     1
# West Indies              6
# Name: match_winner, dtype: int64

# %%
# team 2 winning percentage as home team
plt.figure(figsize=(30,20))
plt.title(' Team 2 Winning Percentage as home team')
plt.pie(list(home_team_two['match_winner'].value_counts()), labels=list(home_team_two['match_winner'].value_counts().keys()), autopct='%0.1f%%')
plt.show()

# %%
home_team_twoo = home_team_two['team_2'].value_counts(sort=True).sort_index()
match_wins = bowling_first['match_winner'].value_counts(sort=True).sort_index()

# %%
# plot match wins as home team for team 2
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Team')
ax1.set_ylabel('Team 2 as home team')
ax1.set_title("Team 2")
home_team_twoo.plot(kind='bar')

ax2 = fig.add_subplot(122)
match_wins.plot(kind='bar')
ax2.set_xlabel('Team')
ax2.set_ylabel('Count of matches won')
ax2.set_title("Match Winners")
# Out:
# Text(0.5, 1.0, 'Match Winners')

# %%
# team 1 in cities and venues
venue_vs_team_one = match_df[match_df['team_1'] == match_df['match_winner']]

# %%
venue_vs_team_one.head(10)
# Out:
#          dates                    venue          city     home_team  \
# 1   2005-06-13            The Rose Bowl   Southampton       England
# 3   2006-01-09  Brisbane Cricket Ground      Brisbane     Australia
# 5   2006-02-24    New Wanderers Stadium  Johannesburg  South Africa
# 10  2006-12-26                Eden Park      Auckland   New Zealand
# 11  2007-01-09    Sydney Cricket Ground        Sydney     Australia
# 13  2007-06-29          Kennington Oval        London       England
# 17  2007-09-11    New Wanderers Stadium  Johannesburg  South Africa
# 19  2007-09-12                Kingsmead        Durban          none
# 21  2007-09-13    New Wanderers Stadium  Johannesburg          none
# 22  2007-09-13                 Newlands     Cape Town          none
#
#           team_1        team_2   toss_winner toss_decision      umpire_1  \
# 1        England     Australia       England           bat      NJ Llong
# 3      Australia  South Africa     Australia           bat  BNJ Oxenford
# 5   South Africa     Australia  South Africa           bat     M Erasmus
# 10   New Zealand     Sri Lanka   New Zealand         field     BF Bowden
# 11     Australia       England     Australia           bat     PD Parker
# 13       England   West Indies   West Indies           bat      IJ Gould
# 17  South Africa   West Indies  South Africa         field     MR Benson
# 19      Pakistan      Scotland      Scotland         field      SJ Davis
# 21    Bangladesh   West Indies    Bangladesh         field     MR Benson
# 22       England      Zimbabwe       England           bat     Asad Rauf
#
#       umpire_2  match_winner
# 1    JW Lloyds       England
# 3     RL Parry     Australia
# 5    KH Hurter  South Africa
# 10     AL Hill   New Zealand
# 11    RL Parry     Australia
# 13    NJ Llong       England
# 17   DJ Harper  South Africa
# 19  SJA Taufel      Pakistan
# 21    NJ Llong    Bangladesh
# 22     AL Hill       England

# %%
#team 1 and venue relationship 
team_one_venue = venue_vs_team_one.groupby('team_1')['venue'].sum()
team_one_venue.sort_values(axis=0, ascending=False, inplace=True)

# %%
team_one_venue
# Out:
# team_1
# Bermuda                  White Hill FieldWhite Hill FieldWhite Hill Field
# Kenya                   Wanderers Cricket GroundWanderers Cricket Grou...
# Namibia                 United Cricket Club GroundUnited Cricket Club ...
# Sri Lanka               Trent BridgeKennington OvalProvidence StadiumP...
# England                 The Rose BowlKennington OvalNewlandsOld Traffo...
# United Arab Emirates    Sheikh Zayed StadiumICC AcademySheikh Zayed St...
# Zimbabwe                Queens Sports ClubHarare Sports ClubHarare Spo...
# Hong Kong               P Sara OvalCivil Service Cricket ClubSheikh Za...
# Bangladesh              New Wanderers StadiumShere Bangla National Sta...
# South Africa            New Wanderers StadiumNew Wanderers StadiumNewl...
# India                   New Wanderers StadiumBrabourne StadiumTrent Br...
# Romania                                      Moara Vlasiei Cricket Ground
# Bulgaria                                     Moara Vlasiei Cricket Ground
# Uganda                           Lugogo Cricket OvalKyambogo Cricket Oval
# Nepal                   LordsAl Amerat Cricket Ground Oman Cricket Min...
# Malaysia                Kinrara Academy OvalKinrara Academy OvalKinrar...
# Maldives                                             Kinrara Academy Oval
# Pakistan                KingsmeadKingsmeadNew Wanderers StadiumNationa...
# Jersey                  King George V Sports GroundSheikh Zayed Stadiu...
# Denmark                 King George V Sports GroundKing George V Sport...
# Guernsey                King George V Sports GroundKing George V Sport...
# West Indies             Kensington OvalQueens Park OvalWarner ParkProv...
# Singapore               Indian Association GroundIndian Association Gr...
# Kuwait                  Indian Association GroundAl Amerat Cricket Gro...
# Canada                  ICC Global Cricket AcademyWhite Hill FieldWhit...
# Scotland                             Grange Cricket Club GroundVRA Ground
# New Zealand             Eden ParkSeddon ParkAMI StadiumWestpac Stadium...
# Afghanistan             Dubai International Cricket StadiumDubai Inter...
# Germany                                        College FieldCollege Field
# Netherlands             Civil Service Cricket ClubSportpark WestvlietS...
# Ireland                 Civil Service Cricket ClubDubai International ...
# Australia               Brisbane Cricket GroundSydney Cricket GroundNe...
# Papua New Guinea        Amini ParkAmini ParkAmini ParkDubai Internatio...
# Philippines                                                    Amini Park
# Oman                    Al Amerat Cricket Ground Oman Cricket Ministry...
# Bahrain                 Al Amerat Cricket Ground Oman Cricket Ministry...
# Name: venue, dtype: object

# %%
# team 1 winning in venues
plt.figure(figsize=(50,30))
plt.title(' Team 1 Winning Venues')
plt.scatter(venue_vs_team_one['team_1'], venue_vs_team_one['venue'])
plt.show()

# %%
# team 1 winning in cities
plt.figure(figsize=(50,30))
plt.title(' Team 1 Winning Cities')
plt.scatter(venue_vs_team_one['team_1'], venue_vs_team_one['city'])
plt.show()

# %%
# team 2 win in cities & venues
venue_vs_team_two = match_df[match_df['team_2'] == match_df['match_winner']]
venue_vs_team_two.head()
# Out:
#         dates                  venue          city     home_team  \
# 0  2005-02-17              Eden Park      Auckland   New Zealand
# 2  2005-10-21  New Wanderers Stadium  Johannesburg  South Africa
# 4  2006-02-16              Eden Park      Auckland   New Zealand
# 6  2006-06-15          The Rose Bowl   Southampton       England
# 7  2006-08-28          County Ground       Bristol       England
#
#          team_1       team_2  toss_winner toss_decision    umpire_1  \
# 0   New Zealand    Australia    Australia           bat   BF Bowden
# 2  South Africa  New Zealand  New Zealand         field   IL Howell
# 4   West Indies  New Zealand  New Zealand         field   BF Bowden
# 6       England    Sri Lanka    Sri Lanka           bat    IJ Gould
# 7       England     Pakistan      England           bat  PJ Hartley
#
#      umpire_2 match_winner
# 0     AL Hill    Australia
# 2  BG Jerling  New Zealand
# 4     AL Hill  New Zealand
# 6    NJ Llong    Sri Lanka
# 7    NJ Llong     Pakistan

# %%
#team 2 and venue relationship 
team_two_venue = venue_vs_team_two.groupby('team_2')['venue'].sum()
team_two_venue.sort_values(axis=0, ascending=False, inplace=True)
team_two_venue
# Out:
# team_2
# Nepal                       Zahur Ahmed Chowdhury StadiumZahur Ahmed Chowd...
# Hong Kong                   Zahur Ahmed Chowdhury StadiumThe VillageThe Vi...
# Maldives                    Tribhuvan University International Cricket Ground
# Ireland                     Trent BridgeMombasa Sports Club GroundMombasa ...
# Sri Lanka                   The Rose BowlWestpac StadiumNew Wanderers Stad...
# Italy                                Sportpark MaarschalkerweerdCollege Field
# Oman                        Sheikh Zayed StadiumSheikh Zayed StadiumKhan S...
# Zimbabwe                    NewlandsQueens Park OvalSylhet International C...
# India                       New Wanderers StadiumKingsmeadKingsmeadKingsme...
# New Zealand                 New Wanderers StadiumEden ParkKingsmeadNew Wan...
# United States of America                     National StadiumWhite Hill Field
# Bermuda                              National StadiumBermuda National Stadium
# Romania                                          Moara Vlasiei Cricket Ground
# Nigeria                              Lugogo Cricket OvalKyambogo Cricket Oval
# Netherlands                 LordsDubai International Cricket StadiumDubai ...
# Namibia                     Kyambogo Cricket OvalKyambogo Cricket OvalKyam...
# Malaysia                    Kinrara Academy OvalIndian Association GroundT...
# Thailand                                                 Kinrara Academy Oval
# Germany                     King George V Sports GroundKing George V Sport...
# Jersey                      King George V Sports GroundCollege FieldTolera...
# Guernsey                             King George V Sports GroundCollege Field
# United Arab Emirates        Khan Shaheb Osman Ali StadiumKhan Shaheb Osman...
# West Indies                 Kennington OvalSt Georges ParkKennington OvalL...
# South Africa                Kennington OvalLordsTrent BridgeTrent BridgeKe...
# Qatar                       Indian Association GroundIndian Association Gr...
# Singapore                   ICC AcademyICC Academy Ground No 2Terdthai Cri...
# Bangladesh                  Gymkhana Club GroundCivil Service Cricket Club...
# Afghanistan                 Grange Cricket Club GroundQueens Sports ClubQu...
# Australia                   Eden ParkWestpac StadiumBeausejour StadiumNewl...
# England                     Eden ParkJade StadiumOld TraffordNew Wanderers...
# Kenya                       Dubai International Cricket StadiumICC Global ...
# Pakistan                    County GroundGymkhana Club GroundGymkhana Club...
# Papua New Guinea            Civil Service Cricket ClubThe VillageTony Irel...
# Scotland                    Civil Service Cricket ClubDubai International ...
# Vanuatu                     Amini ParkKinrara Academy OvalKinrara Academy ...
# Kuwait                      Al Amerat Cricket Ground Oman Cricket Ministry...
# Name: venue, dtype: object

# %%
# team 2 winnning in venues
plt.figure(figsize=(50,30))
plt.title(' Team 2 Winning Venues')
plt.scatter(venue_vs_team_two['team_2'], venue_vs_team_two['venue'])
plt.show()

# %%
# team 2 winning in cities
plt.figure(figsize=(50,30))
plt.title(' Team 2 Winning Cities')
plt.scatter(venue_vs_team_two['team_2'], venue_vs_team_two['city'])
plt.show()

# %% [markdown]
# # Feature Selection

# %%
# drop dates, umpire 1 & umpire 2 from datafram
mod_match_df = match_df.drop(["dates", "umpire_1", "umpire_2" ], axis = 1)
mod_match_df.head(10)
# Out:
#                      venue          city     home_team        team_1  \
# 0                Eden Park      Auckland   New Zealand   New Zealand
# 1            The Rose Bowl   Southampton       England       England
# 2    New Wanderers Stadium  Johannesburg  South Africa  South Africa
# 3  Brisbane Cricket Ground      Brisbane     Australia     Australia
# 4                Eden Park      Auckland   New Zealand   West Indies
# 5    New Wanderers Stadium  Johannesburg  South Africa  South Africa
# 6            The Rose Bowl   Southampton       England       England
# 7            County Ground       Bristol       England       England
# 8    New Wanderers Stadium  Johannesburg  South Africa  South Africa
# 9          Westpac Stadium    Wellington   New Zealand   New Zealand
#
#          team_2   toss_winner toss_decision  match_winner
# 0     Australia     Australia           bat     Australia
# 1     Australia       England           bat       England
# 2   New Zealand   New Zealand         field   New Zealand
# 3  South Africa     Australia           bat     Australia
# 4   New Zealand   New Zealand         field   New Zealand
# 5     Australia  South Africa           bat  South Africa
# 6     Sri Lanka     Sri Lanka           bat     Sri Lanka
# 7      Pakistan       England           bat      Pakistan
# 8         India  South Africa           bat         India
# 9     Sri Lanka   New Zealand           bat     Sri Lanka

# %%
mod_match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   venue          971 non-null    object
#  1   city           971 non-null    object
#  2   home_team      971 non-null    object
#  3   team_1         971 non-null    object
#  4   team_2         971 non-null    object
#  5   toss_winner    971 non-null    object
#  6   toss_decision  971 non-null    object
#  7   match_winner   971 non-null    object
# dtypes: object(8)
# memory usage: 60.8+ KB

# %% [markdown]
# ### Using label encoder for Toss decision

# %%
from sklearn.preprocessing import LabelEncoder

ftr_list = ['toss_decision']
encoder = LabelEncoder()
for ftr in ftr_list:
    mod_match_df[ftr] = encoder.fit_transform(mod_match_df[ftr])
    print(encoder.classes_)

mod_match_df.head(10)
# Out:
# ['bat' 'field']
#                      venue          city     home_team        team_1  \
# 0                Eden Park      Auckland   New Zealand   New Zealand
# 1            The Rose Bowl   Southampton       England       England
# 2    New Wanderers Stadium  Johannesburg  South Africa  South Africa
# 3  Brisbane Cricket Ground      Brisbane     Australia     Australia
# 4                Eden Park      Auckland   New Zealand   West Indies
# 5    New Wanderers Stadium  Johannesburg  South Africa  South Africa
# 6            The Rose Bowl   Southampton       England       England
# 7            County Ground       Bristol       England       England
# 8    New Wanderers Stadium  Johannesburg  South Africa  South Africa
# 9          Westpac Stadium    Wellington   New Zealand   New Zealand
#
#          team_2   toss_winner  toss_decision  match_winner
# 0     Australia     Australia              0     Australia
# 1     Australia       England              0       England
# 2   New Zealand   New Zealand              1   New Zealand
# 3  South Africa     Australia              0     Australia
# 4   New Zealand   New Zealand              1   New Zealand
# 5     Australia  South Africa              0  South Africa
# 6     Sri Lanka     Sri Lanka              0     Sri Lanka
# 7      Pakistan       England              0      Pakistan
# 8         India  South Africa              0         India
# 9     Sri Lanka   New Zealand              0     Sri Lanka

# %%
# total occurance of each venues
mod_match_df['venue'].value_counts(sort=True)
# Out:
# Dubai International Cricket Stadium    62
# Sheikh Zayed Stadium                   44
# Shere Bangla National Stadium          44
# R Premadasa Stadium                    26
# New Wanderers Stadium                  24
#                                        ..
# Carrara Oval                            1
# Brabourne Stadium                       1
# Rajiv Gandhi International Stadium      1
# Jade Stadium                            1
# Subrata Roy Sahara Stadium              1
# Name: venue, Length: 138, dtype: int64

# %%
# total occurance of each cities
mod_match_df['city'].value_counts(sort=True)
# Out:
# Dubai           92
# Abu Dhabi       53
# Colombo         37
# Mirpur          35
# Johannesburg    28
#                 ..
# Victoria         1
# St Georges       1
# Paarl            1
# Kimberley        1
# Taunton          1
# Name: city, Length: 117, dtype: int64
